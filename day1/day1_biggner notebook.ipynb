# %% [markdown]
# > ![](/Volumes/dev/chakri/volume/object-model.png)

# %%
print("hello world")

# %%
# %sql
select * from samples.tpch.orders

# %%
# %sql
select o_orderpriority, count(*) as cnt
from samples.tpch.orders
group by o_orderpriority
# Out:
# Databricks visualization. Run in Databricks to view.

# %%
# %sql
use catalog dev;
create schema day2

# %%
# %sql
    
create table dev.chakri.demo(id int primary key , name string);

# %%
# %sql
insert into dev.chakri.demo values(1,'chakri'),(2,'chakri2');
select * from dev.chakri.demo

# %%
# %sql
insert into dev.chakri.demo values(1,'chakri'),(2,'chakri2');
select * from dev.chakri.demo

# %% [markdown]
# ![object-model](/Volumes/dev/chakri/volume/object-model.png)

# %%
# %sql

create table dev.chakri.employee(id varchar(30) primary key , name string, branch string, role string, age int);
    
insert into dev.chakri.employee values('id1','chakri','pune', 'developer', 30),('id2','chakri2','bangalore', 'tester', 30),('id3','chakri3','hyderabad','manager',45);
select * from dev.chakri.employee
