# %%
df=spark.table("dev.chakri_bronze.sales")

# %%
df1=df.dropDuplicates().dropna().drop("ingestion_date",'path')

# %%
df1.write.mode("overwrite").saveAsTable("dev.chakri_silver.sales_cleaned")

# %%
#df1.write.mode("overwrite").saveAsTable("dev.chakri_silver.sales_cleaned")
