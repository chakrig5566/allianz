# %%
# %sql
create view dev.chakri_gold.top_customers1 as 
select customer_id, sum(total_amount) as total from dev.chakri_silver.sales_cleaned group by customer_id order by total desc limit 3

# %%
# %sql
select * from dev.chakri_gold.top_customers
