# %%
# %sql
create schema if not exists dev.chakri_bronze;
create schema if not exists dev.chakri_silver;
create schema if not exists dev.chakri_gold;

# %%
# %python
input_path="/Volumes/dev/naval/project/"

# %%
# %python
from pyspark.sql.functions import *

# %%
# %python
def add_columns(df):
    return df.withColumn("ingestion_date",current_timestamp()).withColumn("path",col("_metadata.file_name"))
